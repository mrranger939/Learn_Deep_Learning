# %%
import pandas as pd 
import numpy as np

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=500, n_features=2, random_state=31, n_informative=1, n_redundant=0, n_classes=2,class_sep=15, n_clusters_per_class=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
class perceptron:
    def __init__(self):
        self.w1 = 1
        self.w2 = 1
        self.b = 1
    def fit(self, X,y, lr=0.001, epochs=1000):
        for j in range(epochs):
            for i in range(X.shape[0]):
                y_cap = self.w1*X[i][0] + self.w2*X[i][1] + self.b
                if y[i]*y_cap < 0:
                    self.w1 = self.w1 - lr*y[i]*X[i][0]
                    self.w2 = self.w2 - lr*y[i]*X[i][1]
                    self.b = self.b - lr*y[i]
        return self.w1, self.w2, self.b

# %%
p = perceptron()
w1, w2, b = p.fit(X, y)

# %%
print(w1, w2, b)
# Out:
# 31.24201497194328 2.8964403367149885 -1.0000000000000016

# %%
m = -(w1/w2)
c = -(b/w2)

print(m,c)
# Out:
# -10.786348531306729 0.3452513719423464

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
